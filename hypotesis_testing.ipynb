# %% [markdown]
# <a href="https://colab.research.google.com/github/pelinumur-maker/dsa210-project-cranberry/blob/main/hypotesis_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hypothesis 1

# %% [markdown]
# AI artists have lower playcount/listener ratio than Non-AI artists.

# %% [markdown]
# Result: Rejected, data shows the opposite. Non-AI artists have significantly higher ratios.

# %% [markdown]
# # Hypothesis 2

# %% [markdown]
# AI artists have fewer Deezer fans than Non-AI artists.

# %% [markdown]
# #Hypothesis 3

# %% [markdown]
# AI artists have fewer last.fm listeners compared to Non-AI artists.

# %% [markdown]
# #Hypothesis 4

# %% [markdown]
# The album_playcount to artist_listeners ratio is lower for AI artists.
